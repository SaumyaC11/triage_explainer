# %%
import pandas as pd

# %%
df = pd.read_csv('src/data/train.csv')

# %%
df.columns
# Out:
# Index(['patient_id', 'site_id', 'triage_nurse_id', 'arrival_mode',
#        'arrival_hour', 'arrival_day', 'arrival_month', 'arrival_season',
#        'shift', 'age', 'age_group', 'sex', 'language', 'insurance_type',
#        'transport_origin', 'pain_location', 'mental_status_triage',
#        'chief_complaint_system', 'num_prior_ed_visits_12m',
#        'num_prior_admissions_12m', 'num_active_medications',
#        'num_comorbidities', 'systolic_bp', 'diastolic_bp',
#        'mean_arterial_pressure', 'pulse_pressure', 'heart_rate',
#        'respiratory_rate', 'temperature_c', 'spo2', 'gcs_total', 'pain_score',
#        'weight_kg', 'height_cm', 'bmi', 'shock_index', 'news2_score',
#        'disposition', 'ed_los_hours', 'triage_acuity'],
#       dtype='str')

# %%
df['sex'].unique()
# Out:
# <ArrowStringArray>
# ['M', 'F', 'Other']
# Length: 3, dtype: str

# %%
df['insurance_type'].unique()
# Out:
# <ArrowStringArray>
# ['public', 'military', 'none', 'private', 'unknown']
# Length: 5, dtype: str

# %%
df['transport_origin'].unique()
# Out:
# <ArrowStringArray>
# [  'public_space',           'home',   'nursing_home',        'outdoor',
#       'workplace', 'other_hospital',         'school']
# Length: 7, dtype: str

# %%
df['pain_location'].unique()
# Out:
# <ArrowStringArray>
# ['extremity',   'abdomen',  'multiple',      'back',   'unknown',      'head',
#      'chest',      'none',    'pelvis']
# Length: 9, dtype: str

# %%
df['mental_status_triage'].unique()
# Out:
# <ArrowStringArray>
# ['drowsy', 'alert', 'unresponsive', 'agitated', 'confused']
# Length: 5, dtype: str

# %%
df['a'].unique()
# Out:
# <ArrowStringArray>
# [ 'Finnish',  'Russian',  'English',   'Arabic', 'Estonian',   'Somali',
#   'Swedish',    'Other']
# Length: 8, dtype: str

# %%
df['age_group'].unique()
# Out:
# <ArrowStringArray>
# ['middle_aged', 'elderly', 'young_adult', 'pediatric']
# Length: 4, dtype: str

# %%
df.head()
# Out:
#      patient_id      site_id triage_nurse_id arrival_mode  arrival_hour  \
# 0  TG-UXRGA9UCO  SITE-TMP-01      NURSE-0033      walk-in             6
# 1  TG-B19DBBS2G  SITE-HEL-01      NURSE-0001      walk-in             6
# 2  TG-GZ97W7M6V  SITE-HEL-02      NURSE-0005      walk-in             8
# 3  TG-THIB2TN9Q  SITE-HEL-02      NURSE-0026       police             7
# 4  TG-J3U3LQ2QY  SITE-HEL-02      NURSE-0044      walk-in             5
#
#   arrival_day  arrival_month arrival_season    shift  age  ... gcs_total  \
# 0      Monday              5         spring  morning   43  ...        14
# 1    Thursday              4         spring  morning   72  ...        15
# 2    Saturday              4         spring  morning   82  ...        15
# 3      Sunday              3         spring  morning   50  ...        15
# 4     Tuesday              5         spring    night   62  ...        15
#
#   pain_score weight_kg height_cm   bmi shock_index news2_score  disposition  \
# ...

# %%
cheif_c = pd.read_csv('data/chief_complaints.csv')

# %%
cheif_c.head()
# Out:
#      patient_id                            chief_complaint_raw  \
# 0  TG-UXRGA9UCO  thunderclap headache, worsening with movement
# 1  TG-B19DBBS2G             contraception advice, intermittent
# 2  TG-GZ97W7M6V          general health question, intermittent
# 3  TG-THIB2TN9Q       erythema migrans tick bite, intermittent
# 4  TG-J3U3LQ2QY             cellulitis localised, intermittent
#
#   chief_complaint_system
# 0           neurological
# 1          genitourinary
# 2                  other
# 3         dermatological
# 4         dermatological

# %%
patient_records = pd.read_csv('data/patient_history.csv')

# %%
patient_records.columns
# Out:
# Index(['patient_id', 'hx_hypertension', 'hx_diabetes_type2',
#        'hx_diabetes_type1', 'hx_asthma', 'hx_copd', 'hx_heart_failure',
#        'hx_atrial_fibrillation', 'hx_ckd', 'hx_liver_disease', 'hx_malignancy',
#        'hx_obesity', 'hx_depression', 'hx_anxiety', 'hx_dementia',
#        'hx_epilepsy', 'hx_hypothyroidism', 'hx_hyperthyroidism', 'hx_hiv',
#        'hx_coagulopathy', 'hx_immunosuppressed', 'hx_pregnant',
#        'hx_substance_use_disorder', 'hx_coronary_artery_disease',
#        'hx_stroke_prior', 'hx_peripheral_vascular_disease'],
#       dtype='str')
